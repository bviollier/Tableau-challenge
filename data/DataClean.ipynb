# %%
import pandas as pd

# %% [markdown]
# # ridership_membership

# %%
q1_2018 = pd.read_csv("ridership_membership/2018_q1.csv")
q2_2018 = pd.read_csv("ridership_membership/2018_q2.csv")
q3_2018 = pd.read_csv("ridership_membership/2018_q3.csv")
q4_2018 = pd.read_csv("ridership_membership/2018_q4.csv")

# %%
q1_2018
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    1/1/2018                                               5499
# 1    1/2/2018                                              18818
# 2    1/3/2018                                              24299
# 3    1/4/2018                                               1922
# 4    1/5/2018                                               4972
# ..        ...                                                ...
# 85  3/27/2018                                              41354
# 86  3/28/2018                                              41880
# 87  3/29/2018                                              39288
# 88  3/30/2018                                              34784
# 89  3/31/2018                                              41779
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                         11483
# 1                                         39352
# ...

# %%
q2_2018
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    4/1/18                                              33148
# 1    4/2/18                                              22062
# 2    4/3/18                                              25883
# 3    4/4/18                                              36755
# 4    4/5/18                                              39814
# ..      ...                                                ...
# 86  6/26/18                                              80643
# 87  6/27/18                                              67647
# 88  6/28/18                                              50431
# 89  6/29/18                                              69856
# 90  6/30/18                                              54713
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                         94040
# 1                                         50418
# 2                                         59477
# ...

# %%
q3_2018
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    7/1/18                                              45265
# 1    7/2/18                                              58633
# 2    7/3/18                                              54882
# 3    7/4/18                                              48368
# 4    7/5/18                                              59471
# ..      ...                                                ...
# 87  9/26/18                                              68007
# 88  9/27/18                                              75370
# 89  9/28/18                                              57230
# 90  9/29/18                                              69321
# 91  9/30/18                                              66224
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                        120484
# 1                                        130122
# 2                                        113998
# ...

# %%
q4_2018
# Out:
#         Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    10/1/18                                              71387
# 1    10/2/18                                              73113
# 2    10/3/18                                              76769
# 3    10/4/18                                              70698
# 4    10/5/18                                              74744
# ..       ...                                                ...
# 87  12/27/18                                              31169
# 88  12/28/18                                              12039
# 89  12/29/18                                              29037
# 90  12/30/18                                              22536
# 91  12/31/18                                              18936
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                        120257
# 1                                        122234
# ...

# %%
data_year = pd.concat([q1_2018,q2_2018,q3_2018,q4_2018], ignore_index=True)

# %%
data_year
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    1/1/2018                                               5499
# 1    1/2/2018                                              18818
# 2    1/3/2018                                              24299
# 3    1/4/2018                                               1922
# 4    1/5/2018                                               4972
# ..        ...                                                ...
# 360  12/27/18                                              31169
# 361  12/28/18                                              12039
# 362  12/29/18                                              29037
# 363  12/30/18                                              22536
# 364  12/31/18                                              18936
#
#      Miles traveled today (midnight to 11:59 pm)  \
# 0                                          11483
# 1                                          39352
# ...

# %% [markdown]
# # tripHistories

# %%
tripdata_201801 = pd.read_csv("tripHistories/201801_tripdata.csv")
tripdata_201802 = pd.read_csv("tripHistories/201802_tripdata.csv")
tripdata_201803 = pd.read_csv("tripHistories/201803_tripdata.csv")
tripdata_201804 = pd.read_csv("tripHistories/201804_tripdata.csv")
tripdata_201805 = pd.read_csv("tripHistories/201805_tripdata.csv")
tripdata_201806 = pd.read_csv("tripHistories/201806_tripdata.csv")
tripdata_201807 = pd.read_csv("tripHistories/201807_tripdata.csv")
tripdata_201808 = pd.read_csv("tripHistories/201808_tripdata.csv")
tripdata_201809 = pd.read_csv("tripHistories/201809_tripdata.csv")
tripdata_201810 = pd.read_csv("tripHistories/201810_tripdata.csv")
tripdata_201811 = pd.read_csv("tripHistories/201811_tripdata.csv")
tripdata_201812 = pd.read_csv("tripHistories/201812_tripdata.csv")

# %%
trip_data_year = pd.concat([tripdata_201801,
                            tripdata_201802,
                            tripdata_201803,
                            tripdata_201804,
                            tripdata_201805,
                            tripdata_201806,
                            tripdata_201807,
                            tripdata_201808,
                            tripdata_201809,
                            tripdata_201810,
                            tripdata_201811,
                            tripdata_201812], ignore_index=True)

# %%
trip_data_year
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1                550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2                510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3                354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4                250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
# ...              ...                       ...                       ...
# 353887          1081  2018-12-22 11:51:46.0600  2018-12-22 12:09:47.4730
# 353888           344  2018-12-25 21:40:09.8660  2018-12-25 21:45:54.2670
# 353889          1233  2018-12-29 12:55:45.9690  2018-12-29 13:16:19.5960
# 353890          1057  2018-12-30 15:32:09.3320  2018-12-30 15:49:46.3510
# 353891           301  2018-12-31 16:34:11.9340  2018-12-31 16:39:13.8340
#
#         start station id start station name  start station latitude  \
# ...

# %%
data_year.to_csv("clean_quarters.csv")
trip_data_year.to_csv("clean_trip_data.csv")
